# %%
import pandas as pd

# %%
path = "/Users/jesussono/PycharmProjects/flask-dash-board/data"

# %%
df = pd.read_csv("/Users/jesussono/PycharmProjects/flask-dash-board/data/performance_analytics_cost_and_ga_metrics.csv",
                index_col=0)

# %%
df.head()
# Out:
#          Date                       Travel Product  Sessions - This Year  \
# 0  2017-01-02  Targaryen Comparestrip Panel Flight                  2601
# 1  2018-01-01  Targaryen Comparestrip Panel Flight                  4677
# 2  2018-12-31  Targaryen Comparestrip Panel Flight                  2119
# 3  2017-01-03  Targaryen Comparestrip Panel Flight                  3374
# 4  2018-01-02  Targaryen Comparestrip Panel Flight                  3017
#
#    Bookings - This Year  Revenue - This Year  Spend - This Year  Day of Month  \
# 0                   102                  0.0               2743             2
# 1                    78                  0.0               1851             1
# 2                    85                  0.0               2772            31
# 3                    98                  0.0               2402             3
# 4                    98                  0.0               3986             2
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26690 entries, 0 to 26689
# Data columns (total 19 columns):
# Date                    26690 non-null object
# Travel Product          26690 non-null object
# Sessions - This Year    26690 non-null int64
# Bookings - This Year    26690 non-null int64
# Revenue - This Year     26690 non-null float64
# Spend - This Year       26690 non-null int64
# Day of Month            26690 non-null int64
# Day of Week             26690 non-null int64
# Week                    26690 non-null int64
# Month                   26690 non-null int64
# Quarter                 26690 non-null int64
# Year                    26690 non-null int64
# Sessions - Last Year    26690 non-null int64
# Bookings - Last Year    26690 non-null int64
# Revenue - Last Year     26690 non-null float64
# Spend - Last Year       26690 non-null int64
# Category                26690 non-null object
# Birst Category          26690 non-null object
# ...
